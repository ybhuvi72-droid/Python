# %%
string = "python"
print(string.capitalize())

string = "pYTHON PROGRAMMING"
print(string.capitalize())

string = "123 python"
print(string.capitalize())
# Out:
# Python
# Python programming
# 123 python

# %%
string = "PYTHON"
print(string.casefold())

string = "Python Programming"
print(string.casefold())

first = "PYTHON"
second = "python"
print(first.casefold() == second.casefold())
# Out:
# python
# python programming
# True

# %%
string = "Python"
print(string.center(12))
print(string.center(12, "-"))

string = "Hi"
print(string.center(10, "*"))
# Out:
#    Python
# ---Python---
# ****Hi****

# %%
string = "banana"
print(string.count("a"))
print(string.count("a", 2))
print(string.count("a", 2, 5))

string = "Python is easy and Python is powerful"
print(string.count("Python"))
# Out:
# 3
# 2
# 1
# 2

# %%
string = "Python"
print(string.encode())
print(string.encode("utf-8"))
print(string.encode("ascii"))

string = "café"
print(string.encode("ascii", errors="ignore"))
# Out:
# b'Python'
# b'Python'
# b'Python'
# b'caf'

# %%
string = "welcome.py"
print(string.endswith(".py"))

string = "image.jpeg"
print(string.endswith((".jpg", ".jpeg", ".png")))

string = "Python Programming"
print(string.endswith("Programming", 7))
print(string.endswith("Program", 7, 14))
# Out:
# True
# True
# True
# True

# %%
string = "Name\tAge"
print(string.expandtabs())
print(string.expandtabs(4))

string = "A\tB\tC"
print(string.expandtabs(2))
# Out:
# Name    Age
# Name    Age
# A B C

# %%
string = "hello world"
print(string.find("world"))

string = "banana"
print(string.find("a", 2))
print(string.find("a", 2, 5))

string = "Python"
print(string.find("Java"))
# Out:
# 6
# 3
# 3
# -1

# %%
string = "My name is {}"
print(string.format("Sachin"))

string = "{} is learning {}"
print(string.format("Sachin", "Python"))

string = "{name} is learning {course}"
print(string.format(name="Riya", course="Python"))

string = "Total marks: {:.2f}"
print(string.format(95.678))
# Out:
# My name is Sachin
# Sachin is learning Python
# Riya is learning Python
# Total marks: 95.68

# %%
student = {"name": "Riya", "course": "Python"}
print("{name} is learning {course}".format_map(student))

marks = {"subject": "Math", "score": 92}
print("{subject}: {score}".format_map(marks))

employee = {"name": "Sachin", "city": "Pune"}
print("{name} lives in {city}".format_map(employee))
# Out:
# Riya is learning Python
# Math: 92
# Sachin lives in Pune

# %%
string = "Python123"
print(string.isalnum())

string = "Python 123"
print(string.isalnum())

string = "Python_123"
print(string.isalnum())

string = "2026"
print(string.isalnum())
# Out:
# True
# False
# False
# True

# %%
string = "Python"
print(string.isalpha())

string = "Python123"
print(string.isalpha())

string = "Python Sachin"
print(string.isalpha())

string = "HelloWorld"
print(string.isalpha())
# Out:
# True
# False
# False
# True

# %%
string = "Python123"
print(string.isascii())

string = "Hello!"
print(string.isascii())

string = "café"
print(string.isascii())
# Out:
# True
# True
# False

# %%
string = "12345"
print(string.isdecimal())

string = "12.5"
print(string.isdecimal())

string = "123abc"
print(string.isdecimal())

string = "2026"
print(string.isdecimal())
# Out:
# True
# False
# False
# True

# %%
string = "2026"
print(string.isdigit())

string = "20a6"
print(string.isdigit())

string = "007"
print(string.isdigit())

string = "12.5"
print(string.isdigit())
# Out:
# True
# False
# True
# False

# %%
string = "student_name"
print(string.isidentifier())

string = "2student"
print(string.isidentifier())

string = "student name"
print(string.isidentifier())

string = "student_name2"
print(string.isidentifier())
# Out:
# True
# False
# False
# True

# %%
string = "python"
print(string.islower())

string = "Python"
print(string.islower())

string = "python123"
print(string.islower())

string = "python_sachin"
print(string.islower())
# Out:
# True
# False
# True
# True

# %%
string = "12345"
print(string.isnumeric())

string = "123abc"
print(string.isnumeric())

string = "007"
print(string.isnumeric())

string = "12.5"
print(string.isnumeric())
# Out:
# True
# False
# True
# False

# %%
string = "Hello Python"
print(string.isprintable())

string = "Hello\nPython"
print(string.isprintable())

string = "123 @ Python"
print(string.isprintable())

string = "Python\tSachin"
print(string.isprintable())
# Out:
# True
# False
# True
# False

# %%
string = "   "
print(string.isspace())

string = "\t\n"
print(string.isspace())

string = " Python "
print(string.isspace())

string = ""
print(string.isspace())
# Out:
# True
# True
# False
# False

# %%
string = "Python Programming"
print(string.istitle())

string = "Python programming"
print(string.istitle())

string = "My Name Is Sachin"
print(string.istitle())

string = "Python_Sachin"
print(string.istitle())
# Out:
# True
# False
# True
# True

# %%
string = "PYTHON"
print(string.isupper())

string = "Python"
print(string.isupper())

string = "PYTHON123"
print(string.isupper())

string = "PYTHON_SACHIN"
print(string.isupper())
# Out:
# True
# False
# True
# True

# %%
words = ["Python", "is", "easy"]
print(" ".join(words))

names = ["Sachin", "Virat", "Rohit"]
print(", ".join(names))

letters = ["P", "Y", "T", "H", "O", "N"]
print("-".join(letters))

string = "ABC"
print("_".join(string))
# Out:
# Python is easy
# Sachin, Virat, Rohit
# P-Y-T-H-O-N
# A_B_C

# %%
string = "Python"
print(string.ljust(10))
print(string.ljust(10, "-"))

string = "Hi"
print(string.ljust(8, "*"))
# Out:
# Python
# Python----
# Hi******

# %%
string = "PYTHON"
print(string.lower())

string = "Python Programming"
print(string.lower())

string = "PYTHON123"
print(string.lower())

string = "Python_Sachin"
print(string.lower())
# Out:
# python
# python programming
# python123
# python_sachin

# %%
string = "   Python"
print(string.lstrip())

string = "___Python_sachin"
print(string.lstrip("_"))

string = "www.example.com"
print(string.lstrip("w."))

string = "Python   "
print(string.lstrip())
# Out:
# Python
# Python_sachin
# example.com
# Python

# %%
table = str.maketrans("is", "at")
text = "This is a cat"
print(text.translate(table))

table = str.maketrans("abc", "123", "x")
text = "abcdex"
print(text.translate(table))

table = str.maketrans("", "", "aei")
text = "hello, amazing world!"
print(text.translate(table))

table = str.maketrans({"a": "@", "b": "8", "c": "("})
text = "abcde"
print(text.translate(table))
# Out:
# That at a cat
# 123de
# hllo, mzng world!
# @8(de

# %%
string = "python@example.com"
print(string.partition("@"))

string = "Python_sachin"
print(string.partition("_"))

string = "one-two-three"
print(string.partition("-"))

string = "hello world"
print(string.partition("-"))
# Out:
# ('python', '@', 'example.com')
# ('Python', '_', 'sachin')
# ('one', '-', 'two-three')
# ('hello world', '', '')

# %%
string = "Mr. Sharma"
print(string.removeprefix("Mr. "))

string = "Python_sachin"
print(string.removeprefix("Python_"))

string = "Hello Python"
print(string.removeprefix("Java"))

string = "test_file.py"
print(string.removeprefix("test_"))
# Out:
# Sharma
# sachin
# Hello Python
# file.py

# %%
string = "report.pdf"
print(string.removesuffix(".pdf"))

string = "Python_sachin"
print(string.removesuffix("_sachin"))

string = "Hello Python"
print(string.removesuffix("Java"))

string = "image_backup.png"
print(string.removesuffix(".png"))
# Out:
# report
# Python
# Hello Python
# image_backup

# %%
string = "I like Java"
print(string.replace("Java", "Python"))

string = "one one one"
print(string.replace("one", "two"))
print(string.replace("one", "two", 2))

string = "Python_sachin"
print(string.replace("_", " "))
# Out:
# I like Python
# two two two
# two two one
# Python sachin

# %%
string = "banana"
print(string.rfind("a"))
print(string.rfind("a", 0, 4))

string = "Python_sachin_python"
print(string.rfind("python"))

string = "Python"
print(string.rfind("Java"))
# Out:
# 5
# 3
# 14
# -1

# %%
string = "banana"
print(string.rindex("a"))
print(string.rindex("a", 0, 4))

string = "Python_sachin_Python"
print(string.rindex("Python"))

string = "Python"
try:
    print(string.rindex("Java"))
except ValueError:
    print("substring not found")
# Out:
# 5
# 3
# 14
# substring not found

# %%
string = "Python"
print(string.rjust(10))
print(string.rjust(10, "-"))

string = "42"
print(string.rjust(5, "0"))
# Out:
#     Python
# ----Python
# 00042

# %%
string = "one-two-three"
print(string.rpartition("-"))

string = "Python_sachin_kumar"
print(string.rpartition("_"))

string = "python@example.com"
print(string.rpartition("@"))

string = "hello world"
print(string.rpartition("-"))
# Out:
# ('one-two', '-', 'three')
# ('Python_sachin', '_', 'kumar')
# ('python', '@', 'example.com')
# ('', '', 'hello world')

# %%
string = "apple,banana,cherry"
print(string.rsplit(","))
print(string.rsplit(",", 1))

string = "Python_sachin_kumar"
print(string.rsplit("_", 1))

string = "Python is easy"
print(string.rsplit())
# Out:
# ['apple', 'banana', 'cherry']
# ['apple,banana', 'cherry']
# ['Python_sachin', 'kumar']
# ['Python', 'is', 'easy']

# %%
string = "Python   "
print(string.rstrip())

string = "Python_sachin___"
print(string.rstrip("_"))

string = "file.txt"
print(string.rstrip(".txt"))

string = "   Python"
print(string.rstrip())
# Out:
# Python
# Python_sachin
# file
#    Python

# %%
string = "Python is easy"
print(string.split())

string = "Python_sachin"
print(string.split(sep="_", maxsplit=-1))

string = "apple,banana,cherry"
print(string.split(","))
print(string.split(",", 1))
# Out:
# ['Python', 'is', 'easy']
# ['Python', 'sachin']
# ['apple', 'banana', 'cherry']
# ['apple', 'banana,cherry']

# %%
string = "Python\nJava\nC++"
print(string.splitlines())
print(string.splitlines(keepends=True))

string = "line1\r\nline2"
print(string.splitlines())

string = "single line"
print(string.splitlines())
# Out:
# ['Python', 'Java', 'C++']
# ['Python\n', 'Java\n', 'C++']
# ['line1', 'line2']
# ['single line']

# %%
string = "Python Programming"
print(string.startswith("P"))
print(string.startswith("Python"))
print(string.startswith("P", 7))
print(string.startswith("Pro", 7))
print(string.startswith("Programming", 7, 18))

string = "main.py"
print(string.startswith(("main", "test")))
# Out:
# True
# True
# True
# True
# True
# True

# %%
string = "   Python   "
print(string.strip())

string = "___Python_sachin___"
print(string.strip("_"))

string = "...Hello..."
print(string.strip("."))

string = "xyPythonxy"
print(string.strip("xy"))
# Out:
# Python
# Python_sachin
# Hello
# Python

# %%
string = "PyThOn"
print(string.swapcase())

string = "Python_sachin"
print(string.swapcase())

string = "HELLO world"
print(string.swapcase())

string = "Python123"
print(string.swapcase())
# Out:
# pYtHoN
# pYTHON_SACHIN
# hello WORLD
# pYTHON123

# %%
string = "python programming"
print(string.title())

string = "python_sachin"
print(string.title())

string = "hello world 123"
print(string.title())

string = "python's class"
print(string.title())
# Out:
# Python Programming
# Python_Sachin
# Hello World 123
# Python'S Class

# %%
table = str.maketrans("is", "at")
text = "This is a cat"
print(text.translate(table))

table = str.maketrans("abc", "123", "x")
text = "abcdex"
print(text.translate(table))

table = str.maketrans("", "", "aei")
text = "hello, amazing world!"
print(text.translate(table))

table = str.maketrans({"a": "@", "b": "8", "c": "("})
text = "abcde"
print(text.translate(table))
# Out:
# That at a cat
# 123de
# hllo, mzng world!
# @8(de

# %%
string = "python"
print(string.upper())

string = "Python_sachin"
print(string.upper())

string = "python123"
print(string.upper())

string = "Python Programming"
print(string.upper())
# Out:
# PYTHON
# PYTHON_SACHIN
# PYTHON123
# PYTHON PROGRAMMING

# %%
string = "42"
print(string.zfill(5))

string = "-42"
print(string.zfill(5))

string = "123456"
print(string.zfill(4))

string = "7"
print(string.zfill(3))
# Out:
# 00042
# -0042
# 123456
# 007
